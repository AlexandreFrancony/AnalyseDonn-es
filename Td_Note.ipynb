# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("auto.csv", sep = ",")

# %%
df.head(10)
# Out:
#    3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  ...  \
# 0  3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas    std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas    std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas    std   two        sedan  fwd  front   99.8  ...
# 5  1  158         audi  gas    std  four        sedan  fwd  front  105.8  ...
# 6  1    ?         audi  gas    std  four        wagon  fwd  front  105.8  ...
# 7  1  158         audi  gas  turbo  four        sedan  fwd  front  105.8  ...
# 8  0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5  ...
# 9  2  192          bmw  gas    std   two        sedan  rwd  front  101.2  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
# 5  136  mpfi  3.19  3.40   8.5  110  5500  19  25  17710
# 6  136  mpfi  3.19  3.40   8.5  110  5500  19  25  18920
# 7  131  mpfi  3.13  3.40   8.3  140  5500  17  20  23875
# 8  131  mpfi  3.13  3.40   7.0  160  5500  16  22      ?
# 9  108  mpfi  3.50  2.80   8.8  101  5800  23  29  16430
#
# [10 rows x 26 columns]

# %%
col_names = [ "symboling" , "normalized-losses" , "make" , "fuel-type" , "aspiration" , 
"num-of-doors","body-style", "drive-wheels" , "emplacement du moteur" , 
"empattement" , "longueur" , "largeur" , "hauteur" , "poids à vide" , "type de moteur" , 
"nombre de cylindres" , "taille du moteur" , "système de carburant" , "alésage" , 
"course","taux de compression","puissance", "crème-rpm" , "ville-mpg" , "autoroutempg" , "prix" ]

# %%
df.columns = col_names

# %%
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
# 6          1                 ?         audi       gas        std         four
# 7          1               158         audi       gas      turbo         four
# 8          0                 ?         audi       gas      turbo          two
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels emplacement du moteur  empattement  ...  \
# 0  convertible          rwd                 front         88.6  ...
# 1    hatchback          rwd                 front         94.5  ...
# 2        sedan          fwd                 front         99.8  ...
# 3        sedan          4wd                 front         99.4  ...
# 4        sedan          fwd                 front         99.8  ...
# 5        sedan          fwd                 front        105.8  ...
# 6        wagon          fwd                 front        105.8  ...
# 7        sedan          fwd                 front        105.8  ...
# 8    hatchback          4wd                 front         99.5  ...
# 9        sedan          rwd                 front        101.2  ...
#
#    taille du moteur  système de carburant  alésage  course  \
# 0               130                  mpfi     3.47    2.68
# 1               152                  mpfi     2.68    3.47
# 2               109                  mpfi     3.19    3.40
# 3               136                  mpfi     3.19    3.40
# 4               136                  mpfi     3.19    3.40
# 5               136                  mpfi     3.19    3.40
# 6               136                  mpfi     3.19    3.40
# 7               131                  mpfi     3.13    3.40
# 8               131                  mpfi     3.13    3.40
# 9               108                  mpfi     3.50    2.80
#
#   taux de compression puissance  crème-rpm ville-mpg autoroutempg   prix
# 0                 9.0       111       5000        21            27  16500
# 1                 9.0       154       5000        19            26  16500
# 2                10.0       102       5500        24            30  13950
# 3                 8.0       115       5500        18            22  17450
# 4                 8.5       110       5500        19            25  15250
# 5                 8.5       110       5500        19            25  17710
# 6                 8.5       110       5500        19            25  18920
# 7                 8.3       140       5500        17            20  23875
# 8                 7.0       160       5500        16            22      ?
# 9                 8.8       101       5800        23            29  16430
#
# [10 rows x 26 columns]

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels emplacement du moteur  empattement  ...  \
# 199      sedan          rwd                 front        109.1  ...
# 200      sedan          rwd                 front        109.1  ...
# 201      sedan          rwd                 front        109.1  ...
# 202      sedan          rwd                 front        109.1  ...
# 203      sedan          rwd                 front        109.1  ...
#
#      taille du moteur  système de carburant  alésage  course  \
# 199               141                  mpfi     3.78    3.15
# 200               141                  mpfi     3.78    3.15
# 201               173                  mpfi     3.58    2.87
# 202               145                   idi     3.01    3.40
# 203               141                  mpfi     3.78    3.15
#
#     taux de compression puissance  crème-rpm ville-mpg autoroutempg   prix
# 199                 9.5       114       5400        23            28  16845
# 200                 8.7       160       5300        19            25  19045
# 201                 8.8       134       5500        18            23  21485
# 202                23.0       106       4800        26            27  22470
# 203                 9.5       114       5400        19            25  22625
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   symboling              204 non-null    int64
#  1   normalized-losses      204 non-null    object
#  2   make                   204 non-null    object
#  3   fuel-type              204 non-null    object
#  4   aspiration             204 non-null    object
#  5   num-of-doors           204 non-null    object
#  6   body-style             204 non-null    object
#  7   drive-wheels           204 non-null    object
#  8   emplacement du moteur  204 non-null    object
#  9   empattement            204 non-null    float64
#  10  longueur               204 non-null    float64
#  11  largeur                204 non-null    float64
#  12  hauteur                204 non-null    float64
#  13  poids à vide           204 non-null    int64
#  14  type de moteur         204 non-null    object
#  15  nombre de cylindres    204 non-null    object
#  16  taille du moteur       204 non-null    int64
#  17  système de carburant   204 non-null    object
#  18  alésage                204 non-null    object
#  19  course                 204 non-null    object
#  20  taux de compression    204 non-null    float64
#  21  puissance              204 non-null    object
#  22  crème-rpm              204 non-null    object
#  23  ville-mpg              204 non-null    int64
#  24  autoroutempg          204 non-null    int64
#  25  prix                   204 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.6+ KB

# %%
df.shape
# Out:
# (204, 26)

# %%
df.dtypes
# Out:
# symboling                  int64
# normalized-losses         object
# make                      object
# fuel-type                 object
# aspiration                object
# num-of-doors              object
# body-style                object
# drive-wheels              object
# emplacement du moteur     object
# empattement              float64
# longueur                 float64
# largeur                  float64
# hauteur                  float64
# poids à vide               int64
# type de moteur            object
# nombre de cylindres       object
# taille du moteur           int64
# système de carburant      object
# alésage                   object
# course                    object
# taux de compression      float64
# puissance                 object
# crème-rpm                 object
# ville-mpg                  int64
# autoroutempg              int64
# prix                      object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  empattement    longueur     largeur     hauteur  \
# count  204.000000   204.000000  204.000000  204.000000  204.000000
# mean     0.823529    98.806373  174.075000   65.916667   53.749020
# std      1.239035     5.994144   12.362123    2.146716    2.424901
# min     -2.000000    86.600000  141.100000   60.300000   47.800000
# 25%      0.000000    94.500000  166.300000   64.075000   52.000000
# 50%      1.000000    97.000000  173.200000   65.500000   54.100000
# 75%      2.000000   102.400000  183.200000   66.900000   55.500000
# max      3.000000   120.900000  208.100000   72.300000   59.800000
#
#        poids à vide  taille du moteur  taux de compression   ville-mpg  \
# count    204.000000        204.000000           204.000000  204.000000
# mean    2555.602941        126.892157            10.148137   25.240196
# std      521.960820         41.744569             3.981000    6.551513
# min     1488.000000         61.000000             7.000000   13.000000
# 25%     2145.000000         97.000000             8.575000   19.000000
# 50%     2414.000000        119.500000             9.000000   24.000000
# 75%     2939.250000        142.000000             9.400000   30.000000
# max     4066.000000        326.000000            23.000000   49.000000
#
#        autoroutempg
# count     204.000000
# mean       30.769608
# std         6.898337
# min        16.000000
# 25%        25.000000
# 50%        30.000000
# 75%        34.500000
# max        54.000000

# %%
df.describe(include='object')
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                204     204       204        204          204        204
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  40      32       184        167          114         96
#
#        drive-wheels emplacement du moteur type de moteur nombre de cylindres  \
# count           204                   204            204                 204
# unique            3                     2              7                   7
# top             fwd                 front            ohc                four
# freq            120                   201            148                 158
#
#        système de carburant alésage course puissance crème-rpm prix
# count                   204     204    204       204       204  204
# unique                    8      39     37        60        24  186
# top                    mpfi    3.62   3.40        68      5500    ?
# freq                     93      23     20        19        37    4

# %%
df.isna().sum()
# Out:
# symboling                0
# normalized-losses        0
# make                     0
# fuel-type                0
# aspiration               0
# num-of-doors             0
# body-style               0
# drive-wheels             0
# emplacement du moteur    0
# empattement              0
# longueur                 0
# largeur                  0
# hauteur                  0
# poids à vide             0
# type de moteur           0
# nombre de cylindres      0
# taille du moteur         0
# système de carburant     0
# alésage                  0
# course                   0
# taux de compression      0
# puissance                0
# crème-rpm                0
# ville-mpg                0
# autoroutempg            0
# prix                     0
# dtype: int64

# %%
df.replace("?", np.NaN, inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# symboling                 0
# normalized-losses        40
# make                      0
# fuel-type                 0
# aspiration                0
# num-of-doors              2
# body-style                0
# drive-wheels              0
# emplacement du moteur     0
# empattement               0
# longueur                  0
# largeur                   0
# hauteur                   0
# poids à vide              0
# type de moteur            0
# nombre de cylindres       0
# taille du moteur          0
# système de carburant      0
# alésage                   4
# course                    4
# taux de compression       0
# puissance                 2
# crème-rpm                 2
# ville-mpg                 0
# autoroutempg             0
# prix                      4
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 58

# %%
round(df.isna().sum().sum() / df.size * 100, 1)
# Out:
# 1.1

# %%
colonnes = df.columns[df.isna().any()]
df[colonnes]
# Out:
#     normalized-losses num-of-doors alésage course puissance crème-rpm   prix
# 0                 NaN          two    3.47   2.68       111      5000  16500
# 1                 NaN          two    2.68   3.47       154      5000  16500
# 2                 164         four    3.19   3.40       102      5500  13950
# 3                 164         four    3.19   3.40       115      5500  17450
# 4                 NaN          two    3.19   3.40       110      5500  15250
# ..                ...          ...     ...    ...       ...       ...    ...
# 199                95         four    3.78   3.15       114      5400  16845
# 200                95         four    3.78   3.15       160      5300  19045
# 201                95         four    3.58   2.87       134      5500  21485
# 202                95         four    3.01   3.40       106      4800  22470
# 203                95         four    3.78   3.15       114      5400  22625
#
# [204 rows x 7 columns]

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
df.dtypes.value_counts()
# Out:
# object     16
# int64       5
# float64     5
# Name: count, dtype: int64

# %%
df.dropna(inplace = True, thresh = round(len(df) * 0.85), axis = 1)

# %%
col_float = ["alésage", "course", "puissance", "crème-rpm"]

# %%
df[col_float] = df[col_float].astype("float64")

# %%
df.dtypes
# Out:
# symboling                  int64
# make                      object
# fuel-type                 object
# aspiration                object
# num-of-doors              object
# body-style                object
# drive-wheels              object
# emplacement du moteur     object
# empattement              float64
# longueur                 float64
# largeur                  float64
# hauteur                  float64
# poids à vide               int64
# type de moteur            object
# nombre de cylindres       object
# taille du moteur           int64
# système de carburant      object
# alésage                  float64
# course                   float64
# taux de compression      float64
# puissance                float64
# crème-rpm                float64
# ville-mpg                  int64
# autoroutempg              int64
# prix                      object
# dtype: object

# %%
df[col_float] = df[col_float].fillna(df[col_float].mean(axis = 1))

# %%
df.isna().sum()
# Out:
# symboling                0
# make                     0
# fuel-type                0
# aspiration               0
# num-of-doors             2
# body-style               0
# drive-wheels             0
# emplacement du moteur    0
# empattement              0
# longueur                 0
# largeur                  0
# hauteur                  0
# poids à vide             0
# type de moteur           0
# nombre de cylindres      0
# taille du moteur         0
# système de carburant     0
# alésage                  4
# course                   4
# taux de compression      0
# puissance                2
# crème-rpm                2
# ville-mpg                0
# autoroutempg            0
# prix                     4
# dtype: int64
